# %% [markdown]
# <h1><b>YOLOv8 성능 확인하기

# %%
# !pip install torch==2.1.0 torchvision==0.16.0 --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# 필요한 라이브러리 설치하기

# %%
# !pip install --upgrade ultralytics

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...

# %% [markdown]
# <h3><b>1. 예시 사진으로 모델 확인하기

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\jjang\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# 원하는 크기의 YOLO 모델 입력 및 초기화

# %%
model = YOLO("yolov8n.pt") # 원하는 크기 모델 입력(n ~ x)

# %% [markdown]
# 이미지 예측 및 플롯 생성

# %%
result = model.predict("https://ultralytics.com/images/bus.jpg", save=True, conf=0.5)
plots = result[0].plot()

plots_rgb = cv2.cvtColor(plots, cv2.COLOR_BGR2RGB)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\Users\jjang\Desktop\mechArm_jupyter\bus.jpg: 640x480 3 persons, 1 bus, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 114.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict12

# %% [markdown]
# 결과 이미지 출력

# %%
plt.imshow(plots_rgb)
plt.show()

# cv2.imshow("plot", plots)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# <h3><b>2. 웹캠을 통한 실시간 객체인식

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt") 

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    results = model.predict(frame, show=True)
    # print(results)
    if cv2.waitKey(1)&0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 pizza, 78.9ms
# Speed: 1.0ms preprocess, 78.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 76.6ms
# Speed: 2.2ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 75.2ms
# Speed: 1.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 77.5ms
# Speed: 1.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 pizza, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.9ms
# ...
